# %%
import gc
import torch
gc.collect()
torch.cuda.empty_cache()
import utils
utils.print_memory()

import plot_benchmark_turboAE_vanilla as plot_benchmark
plot_benchmark.plot()
# Out:
# Total GPU Memory: 6143.75 MB
# Allocated GPU Memory: 0.0 MB
# Cached GPU Memory: 0.0 MB
# Free GPU Memory: 6143.75 MB
